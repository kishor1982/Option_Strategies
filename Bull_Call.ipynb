# %%
import numpy as np
import strategies

# %% [markdown]
# # Bull Call Spread -> Two Leg Spread using Long and Short Position
# # Market Expectation : Moderately Bullish
# # Spread Exceutes for Debit

# %% [markdown]
# # 1) Buy 1 ATM Call Option -> Leg 1
# # 2) Sell 1 OTM Call Option -> Leg 2
#
# # STRIKES FROM SAME UNDERLYING AND SAME EXPIRY

# %%
# Market Expiry Price (Upper and Lower Range)
MEP = np.arange(16900, 18500, 100)
#------------------------------------
# Lower strike price (Long CALL @ ATM)
LST = 17850
Premium_Paid = 130
#------------------------------------
# Higher Strike Rate (Short CALL @ OTM)
HST = 18000 
Premium_Received = 60
#------------------------------------
df2 = strategies.bull_call_spread(MEP,LST,HST,Premium_Paid,Premium_Received)

df2.head(len(MEP))
# Out:
# Break even (Rs) = 17920
#
# Maximum Profit (Rs) = 80
#
# Maximum Loss (Rs) = 70
#
# ============================================================================
# Strategy Report:
# ============================================================================
# Market Expectation : Moderately Bullish
#
# 1) Strategy makes loss if price goes below  17850 Rs, Loss is restricted to 70 Rs
#
# 2) Break Even (No profit or Loss) when price goes  17920 Rs
#
# 3) Makes money if price goes above  17920 Rs and maximum profit is 80 Rs
# ============================================================================
#     Market Expiry  LS-IV   PP  LS Payoff  HS-IV  PR  HS Payoff  \
# 0           16900      0 -130       -130      0  60         60
# 1           17000      0 -130       -130      0  60         60
# 2           17100      0 -130       -130      0  60         60
# 3           17200      0 -130       -130      0  60         60
# 4           17300      0 -130       -130      0  60         60
# 5           17400      0 -130       -130      0  60         60
# 6           17500      0 -130       -130      0  60         60
# 7           17600      0 -130       -130      0  60         60
# 8           17700      0 -130       -130      0  60         60
# 9           17800      0 -130       -130      0  60         60
# 10          17900     50 -130        -80      0  60         60
# 11          18000    150 -130         20      0  60         60
# 12          18100    250 -130        120    100  60        -40
# 13          18200    350 -130        220    200  60       -140
# 14          18300    450 -130        320    300  60       -240
# 15          18400    550 -130        420    400  60       -340
#
#     Strategy Pay off
# 0                -70
# 1                -70
# 2                -70
# 3                -70
# 4                -70
# 5                -70
# 6                -70
# 7                -70
# 8                -70
# 9                -70
# 10               -20
# 11                80
# 12                80
# 13                80
# 14                80
# 15                80
